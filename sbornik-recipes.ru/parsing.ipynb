# %%
import requests # Импортируем библиотеку requests для запросов
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup для парсинга
import bleach  # Импортируем библиотеку bleach для очистки текста от тэгов
import re      # Импортируем библиотеку для регулярных выражений
import pyautogui  # Импортируем библиотеку для интерактивного ввода
import pandas as pd
import os.path

# %%
# Если файлы таблиц существуют, считываем их
if os.path.isfile('./ingr_df.csv'):
    # Считываем таблицу ингредиентов из файла.
    recipe_df = pd.read_csv('./ingr_df.csv')
else:
    # Создаем таблицу таблицу ингредиентов, если файла с ней нет.
    ingr_df = pd.DataFrame(columns=['ingr_id', 'ingr_name'])

if os.path.isfile('./recipe_df.csv'):
    # Считываем таблицу рецептов из файла.
    recipe_df = pd.read_csv('./recipe_df.csv')
else:
    # Создаем таблицу таблицу рецептов, если файла с ней нет.
    recipe_df = pd.DataFrame(columns=['recipe_id', 'recipe_name', 'ingredients', 'quantity', 'text'])

# %%
# Создаем таблицу рецептов и таблицу ингредиентов. Только на первом проходе. 
# Потом они хранится где-то и пополняются уникальными рецептами и ингредиентами
#ingr_df = pd.DataFrame(columns=['ingr_id', 'ingr_name'])
#recipe_df = pd.DataFrame(columns=['recipe_id', 'recipe_name', 'ingredients', 'quantity', 'text'])
# recipe_df = pd.read_csv('./recipe_df.csv')
# ingr_df = pd.read_csv('./ingr_df.csv')

# %%
def add_ingr(ingr_name, ingr_df):
    """
    Функция добавляет ингредиент с уникальным именем в таблицу ингредиентов

        Args:
            ingr_name (string): наименование ингредиента
            ingr_df (dataframe): таблица ингредиентов
 
        Returns:
            ingr_df (dataframe): таблица ингредиентов с добавленным уникальным ингредиентом    
    """
    # dataframe текущего ингредиента
    curr_ingr = pd.DataFrame(columns=['ingr_id', 'ingr_name'], index=range(1))
    curr_ingr.ingr_name = ingr_name # наименование текущего ингредиента
    curr_ingr.ingr_id = ingr_df.ingr_id.count() # id текущего ингредиента
    # присоединение текущего ингредиента к исходному dataframe 
    ingr_df = pd.concat([ingr_df, curr_ingr], ignore_index=True)
    # удаление ингредиента, если такое наименование уже было в исходном dataframe  
    ingr_df.drop_duplicates(subset=['ingr_name'], inplace=True)
    return ingr_df

# %%
url = pyautogui.prompt(text="Выберите рецепт на сайте https://sbornik-recipes.ru и вставьте его адрес сюда", 
                                    title='Выбор рецепта' , 
                                    default='https://sbornik-recipes.ru/recipes/second/meat/81-kurica-s-kabachkami-v-duhovke.html')

# %%
# https://sbornik-recipes.ru/recipes/first/86-sup-iz-semgi-s-krasnoj-chechevicej.html
# https://sbornik-recipes.ru/recipes/salads/69-salat-s-fasolju-suharikami.html
# https://sbornik-recipes.ru/recipes/second/meat/8-nezhnye-lenivye-golubcy-na-skoruju-ruku.html
# https://sbornik-recipes.ru/recipes/desserts/80-tureckaja-pahlava.html

# %%
# Выполняем GET-запрос, содержимое ответа присваивается переменной response
response = requests.get(url, headers={
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'})
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер

# %%
# Название рецепта
recipe_name = page.title.text
recipe_name
# Out:
# 'Курица с кабачками в духовке рецепт на 4 порции (Европейская кухня)'

# %%
# Текст рецепта
recipe_text = page.find(itemprop="recipeInstructions").text
recipe_text
# Out:
# 'Куриное филе нарезать тонкими ломтиками, после чего хорошо отбить. Кабачок промыть и нарезать колечками потоньше, тоже самое сделать и с луком.Пропустить через пресс чеснок, затем смешать его со специями, солью, и майонезом. Обязательно сделать это в отдельной емкости.Смазать растительным маслом форму для запекания, после чего выложить в ней сначала политый соусом слой из курицы, затем выложить лук, далее кабачки. Смазать остатками соуса из майонеза и отправить форму на пятнадцать минут в разогретую до 180 градусов духовку.Когда блюдо запечется, достать форму и посыпать тертым сыром, и, для образования сырной корочки, отправить в духовку еще на 10 минут.Теперь блюдо можно подавать на стол.'

# %%
# Ингредиенты
ingredients = str(page.find(itemprop="recipeIngredient"))
# Список ингредиентов с невыделенными подзаголовками и неудаленными тэгами
raw_ingr_list = ingredients.split("<br/>")
ingr_list=[]
for ingr_str in raw_ingr_list:
    isSubtitle = re.findall('<b>.*</b>', ingr_str)
    # Подзаголовки в списке ингредиентов
    if len(isSubtitle) != 0:
        # Выделение подзаголовков
        ingr_list.extend(re.split('<b>.*</b>',ingr_str))
    else:
        ingr_list.append(ingr_str)
# Словарь ингредиентов
ingr_dict = {}
for ingr_str in ingr_list:
    # Проверка наличия разделителя названия и меры ингредиента
    a = ingr_str.find('</i><i>')
    if a != -1:  # Если разделитель есть 
        # Разделение ингредиентов на название и меру
        k, v = ingr_str.split('</i><i>')
        # Очистка ингредиентов
        k = bleach.clean(k, tags=[], strip=True).replace('\n','').replace(':','')
        ingr_dict[k] = bleach.clean(v, tags=[], strip=True)
        # Добавление ингредиентов текущего рецепта в таблицу ингредиентов
        ingr_df = add_ingr(k, ingr_df)
print('Словарь ингредиентов текущего рецепта')
ingr_dict
# Out:
# Словарь ингредиентов текущего рецепта
# {'Куриное филе': '500 гр.',
#  'Кабачки': '250 гр.',
#  'Лук': '180 гр.',
#  'Сыр': '150 гр.',
#  'Чеснок': '3 зуб.',
#  'Майонез': '70 гр.',
#  'Соль': '3 гр.',
#  'Специи': 'по вкусу'}

# %%
# Текущий рецепт
recipe = pd.DataFrame(columns=['recipe_id', 'recipe_name', 'ingredients', 'quantity', 'text'])
recipe.ingredients = pd.Series(ingr_dict.keys())
recipe.quantity = pd.Series(ingr_dict.values())
recipe.recipe_name = recipe_name
recipe.text = recipe_text
if len(recipe_df) == 0: #если это первый рецепт в таблице
    recipe.recipe_id = 0
else:
    recipe.recipe_id = recipe_df.recipe_id.iloc[-1]+1
print('Таблица текущего рецепта')
recipe
# Out:
# Таблица текущего рецепта
#    recipe_id                                        recipe_name   ingredients  \
# 0          5  Курица с кабачками в духовке рецепт на 4 порци...  Куриное филе
# 1          5  Курица с кабачками в духовке рецепт на 4 порци...       Кабачки
# 2          5  Курица с кабачками в духовке рецепт на 4 порци...           Лук
# 3          5  Курица с кабачками в духовке рецепт на 4 порци...           Сыр
# 4          5  Курица с кабачками в духовке рецепт на 4 порци...        Чеснок
# 5          5  Курица с кабачками в духовке рецепт на 4 порци...       Майонез
# 6          5  Курица с кабачками в духовке рецепт на 4 порци...          Соль
# 7          5  Курица с кабачками в духовке рецепт на 4 порци...        Специи
#
#    quantity                                               text
# 0   500 гр.  Куриное филе нарезать тонкими ломтиками, после...
# 1   250 гр.  Куриное филе нарезать тонкими ломтиками, после...
# 2   180 гр.  Куриное филе нарезать тонкими ломтиками, после...
# 3   150 гр.  Куриное филе нарезать тонкими ломтиками, после...
# 4    3 зуб.  Куриное филе нарезать тонкими ломтиками, после...
# 5    70 гр.  Куриное филе нарезать тонкими ломтиками, после...
# 6     3 гр.  Куриное филе нарезать тонкими ломтиками, после...
# 7  по вкусу  Куриное филе нарезать тонкими ломтиками, после...

# %%
# Присоединение текущего рецепта к таблице рецептов
recipe_df = pd.concat([recipe_df, recipe], ignore_index=True)
# удаление дубликатов рецептов 
recipe_df.drop_duplicates(inplace=True, subset=['recipe_name', 'ingredients'])

# %%
# Запись в файлы
recipe_df.to_csv('./recipe_df.csv', index=False)
ingr_df.to_csv('./ingr_df.csv', index=False)

# %%
recipe_df
# Out:
#     recipe_id                                        recipe_name  \
# 0           0  Курица с кабачками в духовке рецепт на 4 порци...
# 1           0  Курица с кабачками в духовке рецепт на 4 порци...
# 2           0  Курица с кабачками в духовке рецепт на 4 порци...
# 3           0  Курица с кабачками в духовке рецепт на 4 порци...
# 4           0  Курица с кабачками в духовке рецепт на 4 порци...
# 5           0  Курица с кабачками в духовке рецепт на 4 порци...
# 6           0  Курица с кабачками в духовке рецепт на 4 порци...
# 7           0  Курица с кабачками в духовке рецепт на 4 порци...
# 8           1  Суп из сёмги с красной чечевицей рецепт на 3 п...
# 9           1  Суп из сёмги с красной чечевицей рецепт на 3 п...
# 10          1  Суп из сёмги с красной чечевицей рецепт на 3 п...
# 11          1  Суп из сёмги с красной чечевицей рецепт на 3 п...
# 12          1  Суп из сёмги с красной чечевицей рецепт на 3 п...
# 13          1  Суп из сёмги с красной чечевицей рецепт на 3 п...
# 14          1  Суп из сёмги с красной чечевицей рецепт на 3 п...
# 15          1  Суп из сёмги с красной чечевицей рецепт на 3 п...
# 16          1  Суп из сёмги с красной чечевицей рецепт на 3 п...
# 17          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 18          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 19          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 20          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 21          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 22          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 23          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 24          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 25          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 26          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 27          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 28          2  Турецкая пахлава рецепт на 4 порции (Европейск...
# 29          3  Салат с фасолью сухариками рецепт на 4 порции ...
# 30          3  Салат с фасолью сухариками рецепт на 4 порции ...
# 31          3  Салат с фасолью сухариками рецепт на 4 порции ...
# 32          3  Салат с фасолью сухариками рецепт на 4 порции ...
# 33          3  Салат с фасолью сухариками рецепт на 4 порции ...
# 34          3  Салат с фасолью сухариками рецепт на 4 порции ...
# 35          4  Нежные ленивые голубцы на скорую руку рецепт н...
# 36          4  Нежные ленивые голубцы на скорую руку рецепт н...
# 37          4  Нежные ленивые голубцы на скорую руку рецепт н...
# 38          4  Нежные ленивые голубцы на скорую руку рецепт н...
# 39          4  Нежные ленивые голубцы на скорую руку рецепт н...
# 40          4  Нежные ленивые голубцы на скорую руку рецепт н...
# 41          4  Нежные ленивые голубцы на скорую руку рецепт н...
#
#                       ingredients                     quantity  \
# 0                    Куриное филе                      500 гр.
# 1                         Кабачки                      250 гр.
# 2                             Лук                      180 гр.
# 3                             Сыр                      150 гр.
# 4                          Чеснок                       3 зуб.
# 5                         Майонез                       70 гр.
# 6                            Соль                        3 гр.
# 7                          Специи                     по вкусу
# 8                     Вода тёплая                      250 мл.
# 9   Сёмга или другая красная рыба                  200-300 гр.
# 10               Красная чечевица                       50 гр.
# 11                        Морковь                    1/2 часть
# 12                            Лук                    1/4 часть
# 13                      Картофель                        3 шт.
# 14                          Томат                        1 шт.
# 15                    Соль, перец  по вкусу, 1/4 лимона, укроп
# 16                          Вода                    1,5 литра.
# 17                  Йогурт густой                        100 г
# 18                           Яйцо                        1 шт.
# 19             Масло растительное                       100 мл
# 20                        Крахмал                      1 ст.л.
# 21                           Соль                      щепотка
# 22                 Уксус яблочный                     1 ст. л.
# 23                   Разрыхлитель                       1 ч.л.
# 24                           Мука                    280-300 г
# 25                          Сахар                        250 г
# 26                           Вода                       250 мл
# 27                          Лимон                       долька
# 28                  Орехи грецкие                    100-150 г
# 29        Фасоль консервированная                        1 шт.
# 30      Консервированная кукуруза                        1 шт.
# 31                  Салат Айсберг              1 средний кочан
# 32               Сухарики с сыром                  1 - 2 пачки
# 33                        Майонез                     по вкусу
# 34                         Чеснок                     1 долька
# 35                    Мясной фарш                         1 кг
# 36           Белокочанная капуста                      400 гр.
# 37                   Куриное яйцо                        2 шт.
# 38                   Репчатый лук                      2-3 шт.
# 39                           Соль                     по вкусу
# 40           Перец чёрный молотый                     по вкусу
# 41                        Сметана                     по вкусу
#
#                                                  text
# 0   Куриное филе нарезать тонкими ломтиками, после...
# 1   Куриное филе нарезать тонкими ломтиками, после...
# 2   Куриное филе нарезать тонкими ломтиками, после...
# 3   Куриное филе нарезать тонкими ломтиками, после...
# 4   Куриное филе нарезать тонкими ломтиками, после...
# 5   Куриное филе нарезать тонкими ломтиками, после...
# 6   Куриное филе нарезать тонкими ломтиками, после...
# 7   Куриное филе нарезать тонкими ломтиками, после...
# 8   Рыбу, картофель лук и помидор нарезать кубикам...
# 9   Рыбу, картофель лук и помидор нарезать кубикам...
# 10  Рыбу, картофель лук и помидор нарезать кубикам...
# 11  Рыбу, картофель лук и помидор нарезать кубикам...
# 12  Рыбу, картофель лук и помидор нарезать кубикам...
# 13  Рыбу, картофель лук и помидор нарезать кубикам...
# 14  Рыбу, картофель лук и помидор нарезать кубикам...
# 15  Рыбу, картофель лук и помидор нарезать кубикам...
# 16  Рыбу, картофель лук и помидор нарезать кубикам...
# 17  В миске смешать яйцо, йогурт, растительное мас...
# 18  В миске смешать яйцо, йогурт, растительное мас...
# 19  В миске смешать яйцо, йогурт, растительное мас...
# 20  В миске смешать яйцо, йогурт, растительное мас...
# 21  В миске смешать яйцо, йогурт, растительное мас...
# 22  В миске смешать яйцо, йогурт, растительное мас...
# 23  В миске смешать яйцо, йогурт, растительное мас...
# 24  В миске смешать яйцо, йогурт, растительное мас...
# 25  В миске смешать яйцо, йогурт, растительное мас...
# 26  В миске смешать яйцо, йогурт, растительное мас...
# 27  В миске смешать яйцо, йогурт, растительное мас...
# 28  В миске смешать яйцо, йогурт, растительное мас...
# 29  Берём консервированную фасоль и сливаем рассол...
# 30  Берём консервированную фасоль и сливаем рассол...
# 31  Берём консервированную фасоль и сливаем рассол...
# 32  Берём консервированную фасоль и сливаем рассол...
# 33  Берём консервированную фасоль и сливаем рассол...
# 34  Берём консервированную фасоль и сливаем рассол...
# 35  Представляем оригинальный домашний рецепт лени...
# 36  Представляем оригинальный домашний рецепт лени...
# 37  Представляем оригинальный домашний рецепт лени...
# 38  Представляем оригинальный домашний рецепт лени...
# 39  Представляем оригинальный домашний рецепт лени...
# 40  Представляем оригинальный домашний рецепт лени...
# 41  Представляем оригинальный домашний рецепт лени...

# %%
ingr_df
# Out:
#     ingr_id                      ingr_name
# 0         0                   Куриное филе
# 1         1                        Кабачки
# 2         2                            Лук
# 3         3                            Сыр
# 4         4                         Чеснок
# 5         5                        Майонез
# 6         6                           Соль
# 7         7                         Специи
# 8         8                    Вода тёплая
# 9         9  Сёмга или другая красная рыба
# 10       10               Красная чечевица
# 11       11                        Морковь
# 12       12                      Картофель
# 13       13                          Томат
# 14       14                    Соль, перец
# 15       15                          Вода
# 16       16                  Йогурт густой
# 17       17                           Яйцо
# 18       18             Масло растительное
# 19       19                        Крахмал
# 20       20                 Уксус яблочный
# 21       21                   Разрыхлитель
# 22       22                           Мука
# 23       23                          Сахар
# 24       24                           Вода
# 25       25                          Лимон
# 26       26                  Орехи грецкие
# 27       27        Фасоль консервированная
# 28       28      Консервированная кукуруза
# 29       29                  Салат Айсберг
# 30       30               Сухарики с сыром
# 31       31                    Мясной фарш
# 32       32           Белокочанная капуста
# 33       33                   Куриное яйцо
# 34       34                   Репчатый лук
# 35       35           Перец чёрный молотый
# 36       36                        Сметана
