# %%
import pandas as pd
df = pd.read_csv('ingr_popularity_ver5.csv')
# Исправление опечатки
df.loc[2, 'Название категории'] = 'Сливочное масло'

# %%
ingr_cat_dict = {}
for cat in df['Название категории']:
    cat_list = df[df[
         'Название категории']==cat]['Unnamed: 0'].values
    ingr_cat_dict[cat] = str(cat_list[0]).split(';')
ingr_cat_dict
# Out:
# {'Яйца': ['Куриное яйцо',
#   ' Яичный желток',
#   ' Яичный белок',
#   ' Куриное яйцо (крупное)'],
#  'Мука': ['Пшеничная мука'],
#  'Сливочное масло': ['Сливочное масло'],
#  'Чеснок': ['Чеснок'],
#  'Лук': ['Репчатый лук',
#   ' Красный лук',
#   ' Зеленый лук',
#   ' Лук',
#   ' Лук-порей',
#   ' Белый лук'],
#  'Молоко': ['Молоко',
#   ' Жирное молоко',
#   ' Молоко 3,5%-ное',
#   ' Молоко 3,2%-ное'],
#  'Морковь': ['Морковь'],
#  'Помидоры': ['Помидоры',
#   ' Помидоры черри',
#   ' Крупные помидоры черри',
#   ' Красные помидоры черри',
#   ' Помидоры пелати'],
#  'Картофель': ['Картофель',
#   ' Отварной картофель',
#   ' Картофельное пюре',
#   ' Молодой картофель'],
#  'Сметана': ['Сметана', ' Сметана 20%-ная'],
#  'Курица': ['Куриное филе',
#   ' Куриный бульон',
#   ' Куриная грудка',
#   ' Курица',
#   ' Куриная голень',
#   ' Куриные окорочка',
#   ' Куриные бедра',
#   ' Куриные ножки',
#   ' Куриный фарш',
#   ' Филе куриной грудки',
#   ' Курица'],
# ...
